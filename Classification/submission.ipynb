# %% [markdown]
# 0- Importation des libraires

# %%
import numpy as np
import pandas as pd 
from fcts.general import * 
from fcts.KNN_sel_var import *
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Importation des datasets

# %%
data = pd.read_csv('stars_train.csv')
X_test = pd.read_csv('stars_test_new.csv')

# %%
X = data[data.columns[0:-1]]
y = data[["label"]]

X_tr, X_te, y_tr, y_te = train_test_split(X,y, test_size=0.33, random_state=42)

# %% [markdown]
# Entraînement du modèle choisi

# %%
#Choix des variables 
selection_var = main(X_tr, y_tr, X_te, y_te)

#Creation de la prédiction 
knn_pred = train(X,y,X_test, selection_var)

# %% [markdown]
# Création de la soumission

# %%
#Methode fait-maison mélangée avec KNN 
nom_pred = 'KNN_Sel_Var'
date = '0410'
submission(knn_pred,nom_pred,date, X_test)
# Out:
# 'OK'
